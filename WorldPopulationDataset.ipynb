# %% [markdown]
# <a href="https://colab.research.google.com/github/aschauhan241/git_test/blob/main/WorldPopulationDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Colab Notebooks/world_population.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# This dataset has 17 columns :
#
# Rank: Rank by Population
#
# CCA3: 3 Digit Country/Territories Code
#
# Country: Name of the Country/Territories
#
# Capital: Name of the Capital
#
# Continent: Name of the Continent
#
# 2022 Population: Population of the Country/Territories in the year 2022
#
# 2020 Population: Population of the Country/Territories in the year 2020
#
# 2015 Population: Population of the Country/Territories in the year 2015
#
# 2010 Population: Population of the Country/Territories in the year 2010
#
# 2000 Population: Population of the Country/Territories in the year 2000
#
# 1990 Population: Population of the Country/Territories in the year 1990
#
# 1980 Population: Population of the Country/Territories in the year 1980
#
# 1970 Population: Population of the Country/Territories in the year 1970
#
# Area (km²): Area size of the Country/Territories in square kilometer
#
# Density (per km²): Population Density per square kilometer
#
# Growth Rate: Population Growth Rate by Country/Territories
#
# World Population Percentage: The population percentage by each Country/Territories

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.duplicated().sum() # there are no duplicate values in our dataset
# Out:
# 0

# %%
df.describe().T
# Out:
#                              count          mean           std       min  \
# Rank                         234.0  1.175000e+02  6.769417e+01    1.0000
# 2022 Population              234.0  3.407441e+07  1.367664e+08  510.0000
# 2020 Population              234.0  3.350107e+07  1.355899e+08  520.0000
# 2015 Population              234.0  3.172996e+07  1.304050e+08  564.0000
# 2010 Population              234.0  2.984524e+07  1.242185e+08  596.0000
# 2000 Population              234.0  2.626947e+07  1.116982e+08  651.0000
# 1990 Population              234.0  2.271022e+07  9.783217e+07  700.0000
# 1980 Population              234.0  1.898462e+07  8.178519e+07  733.0000
# 1970 Population              234.0  1.578691e+07  6.779509e+07  752.0000
# Area (km²)                   234.0  5.814494e+05  1.761841e+06    1.0000
# Density (per km²)            234.0  4.521270e+02  2.066122e+03    0.0261
# Growth Rate                  234.0  1.009577e+00  1.338498e-02    0.9120
# ...

# %%
df.describe().T.sort_values(ascending=False, by="mean").style.background_gradient(cmap = "BuGn")
# Out:
# <style type="text/css">
# #T_58a5b_row0_col0, #T_58a5b_row1_col0, #T_58a5b_row2_col0, #T_58a5b_row3_col0, #T_58a5b_row4_col0, #T_58a5b_row5_col0, #T_58a5b_row6_col0, #T_58a5b_row7_col0, #T_58a5b_row8_col0, #T_58a5b_row8_col3, #T_58a5b_row9_col0, #T_58a5b_row9_col1, #T_58a5b_row9_col2, #T_58a5b_row9_col3, #T_58a5b_row9_col4, #T_58a5b_row9_col5, #T_58a5b_row9_col6, #T_58a5b_row9_col7, #T_58a5b_row10_col0, #T_58a5b_row10_col1, #T_58a5b_row10_col2, #T_58a5b_row10_col3, #T_58a5b_row10_col4, #T_58a5b_row10_col5, #T_58a5b_row10_col6, #T_58a5b_row10_col7, #T_58a5b_row11_col0, #T_58a5b_row11_col1, #T_58a5b_row11_col2, #T_58a5b_row11_col3, #T_58a5b_row11_col4, #T_58a5b_row11_col5, #T_58a5b_row11_col6, #T_58a5b_row11_col7, #T_58a5b_row12_col0, #T_58a5b_row12_col1, #T_58a5b_row12_col2, #T_58a5b_row12_col3, #T_58a5b_row12_col4, #T_58a5b_row12_col5, #T_58a5b_row12_col6, #T_58a5b_row12_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# ...

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
df.corr()
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.358361        -0.355854
# 2022 Population             -0.358361         1.000000         0.999946
# 2020 Population             -0.355854         0.999946         1.000000
# 2015 Population             -0.351222         0.999490         0.999763
# 2010 Population             -0.347461         0.998629         0.999105
# 2000 Population             -0.341057         0.994605         0.995583
# 1990 Population             -0.336152         0.987228         0.988724
# 1980 Population             -0.335246         0.980285         0.982121
# 1970 Population             -0.335379         0.973162         0.975254
# Area (km²)                  -0.383774         0.453411         0.454993
# Density (per km²)            0.129436        -0.027618        -0.027358
# Growth Rate                 -0.224561        -0.020863        -0.025116
# ...

# %% [markdown]
# #Explatory Data Analysis:

# %% [markdown]
# <b>Population Analysis Of Continents<b>

# %%
features = df.columns

# %%
df.groupby('Continent').mean().sort_values(by = "Density (per km²)",ascending = False).style.background_gradient(cmap = "BuGn")
# Out:
# <style type="text/css">
# #T_d2183_row0_col0, #T_d2183_row1_col11, #T_d2183_row3_col1, #T_d2183_row3_col2, #T_d2183_row3_col3, #T_d2183_row3_col4, #T_d2183_row3_col5, #T_d2183_row3_col6, #T_d2183_row3_col7, #T_d2183_row3_col8, #T_d2183_row3_col9, #T_d2183_row3_col12, #T_d2183_row5_col10 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_d2183_row0_col1, #T_d2183_row0_col2, #T_d2183_row0_col3, #T_d2183_row0_col4, #T_d2183_row0_col5, #T_d2183_row0_col6, #T_d2183_row0_col7, #T_d2183_row0_col8, #T_d2183_row0_col10, #T_d2183_row0_col12, #T_d2183_row3_col0, #T_d2183_row4_col11, #T_d2183_row5_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d2183_row0_col9 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_d2183_row0_col11 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_d2183_row1_col0 {
#   background-color: #85cfbb;
#   color: #000000;
# }
# #T_d2183_row1_col1, #T_d2183_row1_col12 {
#   background-color: #e3f4f7;
#   color: #000000;
# ...

# %%
import plotly.express as px

fig = px.choropleth(df,
                    locations='Country',
                    locationmode='country names',
                    color='2022 Population',  
                    hover_name='Country',                    
                    title = '2022 Population',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df,
                    locations='Country',
                    locationmode='country names',
                    color='2020 Population',  
                    hover_name='Country',                    
                    title = '2020 Population',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df,
                    locations='Country',
                    locationmode='country names',
                    color='2015 Population',  # we indicate the year we are interested in
                    hover_name='Country',                    
                    title = '2015 Population',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df,
                    locations='Country',
                    locationmode='country names',
                    color='World Population Percentage', 
                    hover_name='Country',                    
                    title = 'World Population Percentage',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df,
                    locations='Country',
                    locationmode='country names',
                    color='Growth Rate', 
                    hover_name='Country',                    
                    title = 'Growth Rate',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
country=df['Continent'].value_counts()
fig=px.bar(x=country.index,
          y=country.values,
          color=country.index,
          color_discrete_sequence=px.colors.sequential.BuGn,
          text=country.values,
          title= 'Number of Countries By Continent',
          template= 'plotly_dark')
fig.update_layout(xaxis_title="Continent",
                 yaxis_title="Count",
                 font=dict(size=15, family="Franklin Gothic"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_most_population = df.groupby(by='Country')['2022 Population'].sum().sort_values(ascending=False).head(10)

fig=px.bar(x=top_most_population.index,
          y=top_most_population.values,
          color=top_most_population.index,
          color_discrete_sequence=px.colors.sequential.BuGn,
          text=top_most_population.values,
          title= 'Top 10 most populace countries',
          template= 'plotly_dark')
fig.update_layout(xaxis_title="Countries",
                 yaxis_title="Population",
                 font=dict(size=15, family="Franklin Gothic"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 df.groupby(by='Country')['2022 Population'].sum()
# Out:
# Continent
# Africa            218541212
# Asia             1425887337
# Europe            144713314
# North America     338289857
# Oceania            26177413
# South America     215313498
# Name: 2022 Population, dtype: int64
